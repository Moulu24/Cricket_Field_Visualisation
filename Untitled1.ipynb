# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path

# %%
elle = patches.Ellipse((0.5,0.5), 1, 0.6 , facecolor = 'darkgreen', zorder = 0)
fig,ax = plt.subplots(1,figsize = (8,8))
ax.add_patch(elle)

inner_elle = patches.Ellipse((0.5,0.5) , 0.6, 0.5 , edgecolor = 'white' ,fill = 0  ,ls = '-.' , zorder = 0 )
ax.add_patch(inner_elle)
#path = Path([[0.3,0.3],[0.7,0.3],[0.7,0.7],[0.3,0.7],[0.3,0.3]])
#path = Path([[0.3,0.3],[0.6,0.3],[0.61,0.31],[0.62,0.34],[0.63,0.39],[0.7,0.4],[0.7,0.7],[0.3,0.7],[0.3,0.3]])
#poll = patches.PathPatch(path, fill = 0, ec = 'white',zorder = 0, ls = '--')
#ax.add_patch(poll)

rect = patches.Rectangle((0.425,0.35),0.15,0.3, facecolor = 'peru', alpha = 1, zorder = 0)
ax.add_patch(rect)

rect1 = patches.Rectangle((0.45,0.6),0.1,0.03, ec = 'white', fill = 0, zorder = 0)
ax.add_patch(rect1)

rect2 = patches.Rectangle((0.45,0.375),0.1,0.03, ec = 'white', fill = 0, zorder = 0)
ax.add_patch(rect2)

rect3 = patches.Rectangle((0.465,0.6),0.07,0.03, ec = 'white', fill = 0, zorder = 0)
ax.add_patch(rect3)

rect4 = patches.Rectangle((0.465,0.375),0.07,0.03, ec = 'white', fill = 0, zorder = 0)
ax.add_patch(rect4)

ax.plot([0.425,0.45],[0.6,0.6], linewidth = 1, color = 'white')
ax.plot([0.574,0.55],[0.6,0.6], linewidth = 1, color = 'white')
ax.plot([0.45,0.45],[0.65,0.6], linewidth = 1, color = 'white')
ax.plot([0.55,0.55],[0.65,0.6], linewidth = 1, color = 'white')

ax.plot([0.425,0.45],[0.405,0.405], linewidth = 1, color = 'white')
ax.plot([0.55,0.574],[0.405,0.405], linewidth = 1, color = 'white')
ax.plot([0.45,0.45],[0.375,0.352], linewidth = 1, color = 'white')

ax.plot([0.55,0.55],[0.375,0.352], linewidth = 1, color = 'white')

plt.axis('off')

#circ = patches.CirclePolygon((0.5,0.5),0.25,resolution = 15, fill = 0, zorder = 1)
#ax.add_patch(circ)

ax.scatter([0.65,0.2,0.3,0.5,0.5,0.15,0.8,0.8,0.43,0.38,0.33],[0.4,0.7,0.5,0.22,0.69,0.35,0.3,0.69,0.71,0.7,0.68] , c = 'white' )

plt.savefig('My_cricket')
